# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
import re

# %% [markdown]
# # Load Data

# %%
df = pd.read_csv(r"..\data\Kaggle_dataset\harvard_reviews.csv", encoding='latin-1')

print("harvard_reviews dataset shape:", df.shape)
# Out:
# harvard_reviews dataset shape: (3184, 7)

# %% [markdown]
# # View Data

# %%
print("\nharvard_reviews Dataset:")
df.head()
df.tail()
df.sample(5)
df.info()
df.describe()
# Out:
# harvard_reviews Dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3184 entries, 0 to 3183
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ï»¿"published_date"  3184 non-null   object
#  1   published_platform   3184 non-null   object
#  2   rating               3184 non-null   int64
#  3   type                 3184 non-null   object
#  4   helpful_votes        3184 non-null   int64
#  5   title                3184 non-null   object
#  6   text                 3184 non-null   object
# dtypes: int64(2), object(5)
# memory usage: 174.3+ KB
#             rating  helpful_votes
# count  3184.000000    3184.000000
# mean      4.456658       0.498744
# std       0.744024       2.819638
# min       1.000000       0.000000
# 25%       4.000000       0.000000
# 50%       5.000000       0.000000
# 75%       5.000000       1.000000
# max       5.000000     111.000000

# %% [markdown]
# # Rename columns

# %%
df.rename(columns={'text': 'Review', 'rating': 'Rating' }, inplace=True)

# %% [markdown]
# # Count missing values

# %%
# Count missing values in each column
missing_data = df.isnull().sum()

print("\nMissing Data Count per Column:")
print(missing_data)

# Also show total missing values in dataset
print("\nTotal Missing Values in Dataset:", missing_data.sum())
# Out:
# Missing Data Count per Column:
# ï»¿"published_date"    0
# published_platform     0
# Rating                 0
# type                   0
# helpful_votes          0
# title                  0
# Review                 0
# dtype: int64
#
# Total Missing Values in Dataset: 0

# %% [markdown]
# #  Handle Missing Data

# %%
# 1. Count missing values in Review and rating
print("Missing values in Review and Rating:")
print(df[['Review', 'Rating']].isnull().sum())

# 2. Drop rows where Review or rating is missing
df.dropna(subset=['Review', 'Rating'], inplace=True)

# 3. Reset index after dropping rows
df.reset_index(drop=True, inplace=True)

# 4.  after handling missing data
print("\nAfter handling missing data:")
print(df[['Review', 'Rating']].isnull().sum())
print("Dataset shape:", df.shape)

df.info()
df.head()
# Out:
# Missing values in Review and Rating:
# Review    0
# Rating    0
# dtype: int64
#
# After handling missing data:
# Review    0
# Rating    0
# dtype: int64
# Dataset shape: (3184, 7)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3184 entries, 0 to 3183
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ï»¿"published_date"  3184 non-null   object
#  1   published_platform   3184 non-null   object
#  2   Rating               3184 non-null   int64
#  3   type                 3184 non-null   object
#  4   helpful_votes        3184 non-null   int64
#  5   title                3184 non-null   object
#  6   Review               3184 non-null   object
# dtypes: int64(2), object(5)
# memory usage: 174.3+ KB
#          ï»¿"published_date" published_platform  Rating    type  \
# 0  2023-12-28T08:02:14-05:00             Mobile       5  review
# ...

# %% [markdown]
# # Count Number of duplicates

# %%
# Count  duplicates 
duplicate_count = df.duplicated(subset=['Review', 'Rating']).sum()
print(f"Number of duplicates: {duplicate_count}")

# view duplicate rows
duplicates = df[df.duplicated(subset=['Review', 'Rating'], keep=False)]
print("Sample duplicate rows:")
print(duplicates.head())
# Out:
# Number of duplicates: 0
# Sample duplicate rows:
# Empty DataFrame
# Columns: [ï»¿"published_date", published_platform, Rating, type, helpful_votes, title, Review]
# Index: []

# %% [markdown]
# #  Remove Duplicates

# %%
# 1. Remove exact duplicates (same Review + rating)
df = df.drop_duplicates(subset=['Review', 'Rating'], keep='first')

# 2. Remove conflicting reviews (same Review text, different ratings)
conflict_idx = df[df.duplicated(subset=['Review'], keep=False) & 
                  ~df.duplicated(subset=['Review', 'Rating'], keep=False)].index
df.drop(index=conflict_idx, inplace=True)

# 3. Reset index
df.reset_index(drop=True, inplace=True)

print("After removing duplicates and conflicts:", df.shape)
df.head()
# Out:
# After removing duplicates and conflicts: (3184, 7)
#          ï»¿"published_date" published_platform  Rating    type  \
# 0  2023-12-28T08:02:14-05:00             Mobile       5  review
# 1  2023-12-12T00:38:26-05:00            Desktop       4  review
# 2  2023-12-10T08:21:35-05:00             Mobile       3  review
# 3  2023-11-07T21:20:21-05:00            Desktop       4  review
# 4  2023-10-02T17:40:42-04:00            Desktop       5  review
#
#    helpful_votes                                              title  \
# 0              0                 Best classes and good environment
# 1              0                                 Harvard University
# 2              0                                 Walk around campus
# 3              0                     Interesting Harvard University
# 4              0  Lovely university campus has many historic and...
#
#                                               Review
# 0  Good thanks for everything good work group ð...
# ...

# %% [markdown]
# #  Selecting Columns

# %%
df = df[['Rating','Review']]

print("Final dataset columns:", df.columns)

print("Final dataset shape:", df.shape)
# Out:
# Final dataset columns: Index(['Rating', 'Review'], dtype='object')
# Final dataset shape: (3184, 2)

# %% [markdown]
# #  Filtering Rows

# %%
df_filtered = df[(df['Rating'] >= 1) & (df['Rating'] <= 5)]

print("Filtered dataset shape:", df_filtered.shape)
df_filtered.head()
# Out:
# Filtered dataset shape: (3184, 2)
#    Rating                                             Review
# 0       5  Good thanks for everything good work group ð...
# 1       4  Harvard University was founded in 1636 and is ...
# 2       3  We did a walk around most of the Harvard Campu...
# 3       4  We had a walk through the university grounds w...
# 4       5  Finally made it to Harvard!!  This iconic univ...

# %% [markdown]
# # Grouping and Aggregation

# %%
# Count of reviews per rating
review_count_per_rating = df.groupby('Rating')['Review'].count()
print("Number of Reviews per Rating:\n", review_count_per_rating)

# Average rating 
average_rating = df['Rating'].mean()
print("\nAverage Rating of Dataset:", average_rating)

# Min and Max rating
min_rating = df['Rating'].min()
max_rating = df['Rating'].max()
print("Rating Range: {} to {}".format(min_rating, max_rating))
# Out:
# Number of Reviews per Rating:
#  Rating
# 1      14
# 2      46
# 3     264
# 4    1008
# 5    1852
# Name: Review, dtype: int64
#
# Average Rating of Dataset: 4.456658291457287
# Rating Range: 1 to 5

# %% [markdown]
# # Cleaning text - remove emojis, special characters, symbols

# %%
def clean_text(text):
    text = re.sub(r'[^A-Za-z0-9\s]+', '', str(text))  # Remove special characters/emojis
    text = re.sub(r'\s+', ' ', text).strip()          # Remove extra spaces
    return text

# Clean Review text
df_filtered.loc[:, 'Review'] = df_filtered['Review'].apply(clean_text)
df_filtered['Review'].head()
# Out:
# 0    Good thanks for everything good work group har...
# 1    Harvard University was founded in 1636 and is ...
# 2    We did a walk around most of the Harvard Campu...
# 3    We had a walk through the university grounds w...
# 4    Finally made it to Harvard This iconic univers...
# Name: Review, dtype: object

# %% [markdown]
# # Remove Very Short Reviews

# %%
# Remove reviews with fewer than 20 characters
df_filtered = df_filtered[df_filtered['Review'].str.len() >= 20]

# Reset index
df_filtered.reset_index(drop=True, inplace=True)

print("After removing very short reviews:", df_filtered.shape)
# Out:
# After removing very short reviews: (3018, 2)

# %% [markdown]
# # Load the new dataset

# %%
df1 = pd.read_csv(r"..\data\Kaggle_dataset\yelp.csv", encoding="latin-1")

# %% [markdown]
# # Rename columns to match your cleaned dataset

# %%
df1.rename(columns={
    "stars": "Rating",
    "text": "Review"
}, inplace=True)


# Select the same columns as df_filtered
df1 = df1[[ "Rating", "Review"]]

# %% [markdown]
# # Count missing values

# %%
# Count missing values in each column
missing_data = df1.isnull().sum()

print("\nMissing Data Count per Column:")
print(missing_data)

# Also show total missing values in dataset
print("\nTotal Missing Values in Dataset:", missing_data.sum())
# Out:
# Missing Data Count per Column:
# Rating    0
# Review    0
# dtype: int64
#
# Total Missing Values in Dataset: 0

# %% [markdown]
# # Count duplicates

# %%
duplicate_count = df1.duplicated(subset=['Review', 'Rating']).sum()
print(f"Number of duplicates: {duplicate_count}")

# view duplicate rows
duplicates = df1[df1.duplicated(subset=['Review', 'Rating'], keep=False)]
print("Sample duplicate rows:")
duplicates.head()
# Out:
# Number of duplicates: 2
# Sample duplicate rows:
#       Rating                                             Review
# 284        5                                      Great service
# 3921       5                                      Great service
# 4372       2  This review is for the chain in general. The l...
# 9680       2  This review is for the chain in general. The l...

# %% [markdown]
# # Remove duplicates

# %%
# 1. Remove exact duplicates (same Review + rating)
df1 = df1.drop_duplicates(subset=['Review', 'Rating'], keep='first')

# 2. Remove conflicting reviews (same Review text, different ratings)
conflict_idx = df1[df1.duplicated(subset=['Review'], keep=False) & 
                  ~df1.duplicated(subset=['Review', 'Rating'], keep=False)].index
df1.drop(index=conflict_idx, inplace=True)

# 3. Reset index
df1.reset_index(drop=True, inplace=True)

print("After removing duplicates and conflicts:", df1.shape)
df1.head()
# Out:
# After removing duplicates and conflicts: (9998, 2)
#    Rating                                             Review
# 0       5  My wife took me here on my birthday for breakf...
# 1       5  I have no idea why some people give bad review...
# 2       4  love the gyro plate. Rice is so good and I als...
# 3       5  Rosie, Dakota, and I LOVE Chaparral Dog Park!!...
# 4       5  General Manager Scott Petello is a good egg!!!...

# %% [markdown]
# # Cleaning text - remove emojis, special characters, symbols

# %%
def clean_text(text):
    text = re.sub(r'[^A-Za-z0-9\s]+', '', str(text))  # Remove special characters/emojis
    text = re.sub(r'\s+', ' ', text).strip()          # Remove extra spaces
    return text

# Clean Review text
df1.loc[:, 'Review'] = df1['Review'].apply(clean_text)
df1['Review'].head()
# Out:
# 0    My wife took me here on my birthday for breakf...
# 1    I have no idea why some people give bad review...
# 2    love the gyro plate Rice is so good and I also...
# 3    Rosie Dakota and I LOVE Chaparral Dog Park Its...
# 4    General Manager Scott Petello is a good egg No...
# Name: Review, dtype: object

# %% [markdown]
# # Remove Very Short Reviews

# %%
# Remove reviews with fewer than 10 characters
df1 = df1[df1['Review'].str.len() >= 20]

# Reset index
df1.reset_index(drop=True, inplace=True)

print("After removing very short reviews:", df1.shape)
# Out:
# After removing very short reviews: (9952, 2)

# %% [markdown]
# # Concatenate with  cleaned dataset

# %%
df_final = pd.concat([df_filtered, df1], axis=0).reset_index(drop=True)

# %% [markdown]
# # duplicates in the combined dataset

# %%
# Check for duplicates in the combined dataset
duplicate_count = df_final.duplicated(subset=['Review', 'Rating']).sum()
print(f"Number of duplicates in combined dataset: {duplicate_count}")

#  remove duplicates if any
df_final = df_final.drop_duplicates(subset=['Review', 'Rating'], keep='first').reset_index(drop=True)

# View final dataset info
print("Final dataset shape:", df_final.shape)
df_final.head()
# Out:
# Number of duplicates in combined dataset: 1
# Final dataset shape: (12969, 2)
#    Rating                                             Review
# 0       5  Good thanks for everything good work group har...
# 1       4  Harvard University was founded in 1636 and is ...
# 2       3  We did a walk around most of the Harvard Campu...
# 3       4  We had a walk through the university grounds w...
# 4       5  Finally made it to Harvard This iconic univers...

# %% [markdown]
# # View and Inspect of Final merged Data

# %%
print("Final merged dataset shape:", df_final.shape)
df_final.head()
df_final.tail()
# Out:
# Final merged dataset shape: (12969, 2)
#        Rating                                             Review
# 12964       3  First visitHad lunch here today used my Groupo...
# 12965       4  Should be called house of deliciousness I coul...
# 12966       4  I recently visited Olive and Ivy for business ...
# 12967       2  My nephew just moved to Scottsdale recently so...
# 12968       5  45 locations all 45 star average I think Arizo...

# %% [markdown]
# # Sorting Data

# %%
df_final_sorted = df_final.sort_values(by='Rating', ascending=False).reset_index(drop=True)
df_final_sorted.head()
# Out:
#    Rating                                             Review
# 0       5  45 locations all 45 star average I think Arizo...
# 1       5  Good thanks for everything good work group har...
# 2       5  Lets seewhat is there NOT to like about Surpri...
# 3       5  Why did I wait so long to try this neighborhoo...
# 4       5  When I lived in Phoenix I was a regular at Fez...

# %%
rating_distribution = df_final_sorted['Rating'].value_counts().sort_index()
print("Rating distribution:\n", rating_distribution)
# Out:
# Rating distribution:
#  Rating
# 1     758
# 2     970
# 3    1705
# 4    4468
# 5    5068
# Name: count, dtype: int64

# %% [markdown]
# # Removing consecutive duplicate words

# %%
# Function to remove consecutive duplicate words
def remove_repeated_words(text):
    # \b(\w+) matches a word, ( \1\b)+ matches one or more consecutive repeats
    return re.sub(r'\b(\w+)( \1\b)+', r'\1', text, flags=re.IGNORECASE)

df_final_sorted['Review'] = df_final_sorted['Review'].apply(remove_repeated_words)
df_final_sorted.head()
# Out:
#    Rating                                             Review
# 0       5  45 locations all 45 star average I think Arizo...
# 1       5  Good thanks for everything good work group har...
# 2       5  Lets seewhat is there NOT to like about Surpri...
# 3       5  Why did I wait so long to try this neighborhoo...
# 4       5  When I lived in Phoenix I was a regular at Fez...

# %% [markdown]
# #  Save Cleaned Dataset

# %%
df_final_sorted.to_csv(r"..\data\cleaned_product_reviews.csv", index=False)

df_final_sorted.to_excel(r"..\data\cleaned_product_reviews.xlsx", index=False)

print("Files saved")
# Out:
# Files saved

# %% [markdown]
# # Data Visualization

# %% [markdown]
# # Rating Distribution (Bar Chart)

# %%
sns.countplot(x='Rating', data=df_final_sorted, color='skyblue')  
plt.title('Rating Distribution')
plt.xlabel('Rating')
plt.ylabel('Number of Reviews')
plt.show()

# %% [markdown]
# #  Rating Distribution (Pie Chart)

# %%
rating_counts = df_final_sorted['Rating'].value_counts().sort_index()

# Labels and values
categories = rating_counts.index
values = rating_counts.values

# Plot pie chart
plt.pie(values, labels=categories, autopct='%1.1f%%', startangle=90)
plt.title("Rating Distribution ")
plt.show()

# %% [markdown]
# # Review Length Distribution (Histogram)

# %%
df_final_sorted['ReviewLength'] = df_final_sorted['Review'].str.len()


sns.histplot(df_final_sorted['ReviewLength'], bins=10, kde=True, color='skyblue')
plt.title('Review Length Distribution')
plt.xlabel('Number of Characters in Review')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# # Boxplot of Review Length per Rating

# %%
sns.boxplot(x='Rating', y='ReviewLength', data=df_final_sorted, color='green')
plt.title('Boxplot of Review Length per Rating')
plt.xlabel('Rating')
plt.ylabel('Review Length')
plt.show()

# %% [markdown]
# # Violin Plot (Density + Distribution of Review Length per Rating)

# %%
sns.violinplot(x='Rating', y='ReviewLength', data=df_final_sorted, color='orange')
plt.title('Violin Plot of Review Length per Rating')
plt.xlabel('Rating')
plt.ylabel('Review Length')
plt.show()

# %% [markdown]
# # Creating  Balanced Dataset

# %%
min_count = 2000  

# List to hold balanced DataFrames
balanced_df_list = []

# Loop through each unique rating
for rating in df_final_sorted['Rating'].unique():
    df_rating = df_final_sorted[df_final_sorted['Rating'] == rating]
    
    if len(df_rating) < min_count:
        # Oversample minority class (with replacement)
        df_rating_balanced = df_rating.sample(min_count, replace=True, random_state=42)
    else:
        # Undersample majority class (without replacement)
        df_rating_balanced = df_rating.sample(min_count, replace=False, random_state=42)
    
    balanced_df_list.append(df_rating_balanced)


df_balanced = pd.concat(balanced_df_list).sample(frac=1, random_state=42).reset_index(drop=True)

print("Balanced Dataset Distribution:\n", df_balanced['Rating'].value_counts())
print("\nBalanced dataset shape:", df_balanced.shape)
df_balanced.head()
# Out:
# Balanced Dataset Distribution:
#  Rating
# 2    2000
# 3    2000
# 5    2000
# 4    2000
# 1    2000
# Name: count, dtype: int64
#
# Balanced dataset shape: (10000, 3)
#    Rating                                             Review  ReviewLength
# 0       2  Ive been to Buffalo Wild Wings before but my f...           818
# 1       3  So let me start by saying the latte was very g...           584
# 2       5  Yknow rarely do I buy the extended warranty th...          1702
# 3       3  I dont like megachain pizza I dont like Domino...           887
# 4       3                        Been closed for a long time            27

# %%
# Sort by Rating
df_balanced_sorted = df_balanced.sort_values(by='Rating').reset_index(drop=True)

# Check distribution again
print(df_balanced_sorted['Rating'].value_counts())

# Show first few rows after sorting
df_balanced_sorted.head()
# Out:
# Rating
# 1    2000
# 2    2000
# 3    2000
# 4    2000
# 5    2000
# Name: count, dtype: int64
#    Rating                                             Review  ReviewLength
# 0       1  Got a padi and the tech stopped for a while to...           368
# 1       1  Easily the worst burrito I have ever had It am...           177
# 2       1  We bought or second Jura Compressa coffee mach...           492
# 3       1  I purchased a pair of Naot Paris sandals 160 w...           992
# 4       1  I have been going to Bosa off and on since the...          1086

# %%
df_balanced_sorted.to_csv(r"..\data\balanced_product_reviews.csv", index=False)

df_balanced_sorted.to_excel(r"..\data\balanced_product_reviews.xlsx", index=False)

print("Balanced dataset files saved")
# Out:
# Balanced dataset files saved

# %% [markdown]
# # Data Visualization of balanced Data

# %% [markdown]
# # Rating Distribution (Bar Chart)

# %%
sns.countplot(x='Rating', data=df_balanced_sorted, color='skyblue')  
plt.title('Rating Distribution')
plt.xlabel('Rating')
plt.ylabel('Number of Reviews')
plt.show()

# %% [markdown]
# # Rating Distribution (Pie Chart)

# %%
rating_counts = df_balanced_sorted['Rating'].value_counts().sort_index()

# Labels and values
categories = rating_counts.index
values = rating_counts.values

# Plot pie chart
plt.pie(values, labels=categories, autopct='%1.1f%%', startangle=90)
plt.title("Rating Distribution ")
plt.show()

# %% [markdown]
# # Creating Imbalanced dataset

# %%
# Remove balanced dataset rows from df_final_sorted
df_remaining = df_final_sorted.merge(df_balanced_sorted[['Rating','Review']], 
                                     on=['Rating','Review'], 
                                     how='left', 
                                     indicator=True)
df_remaining = df_remaining[df_remaining['_merge'] == 'left_only'].drop(columns=['_merge']).reset_index(drop=True)

print("Remaining dataset shape after removing balanced:", df_remaining.shape)

#  Define unbalanced distribution ratios
ratios = {
    1: 0.10,  
    2: 0.15,  
    3: 0.25,  
    4: 0.30,  
    5: 0.20   
}

#  Calculate sample sizes
total_unbalanced = len(df_remaining)
unbalanced_df_list = []

for rating, ratio in ratios.items():
    df_rating = df_remaining[df_remaining['Rating'] == rating]
    sample_size = int(total_unbalanced * ratio)

    if len(df_rating) == 0:
        print(f"Skipping Rating {rating} (no samples left after balancing).")
        continue
    
    if len(df_rating) >= sample_size:
        df_rating_unbalanced = df_rating.sample(sample_size, replace=False, random_state=42)
    else:
        df_rating_unbalanced = df_rating.sample(sample_size, replace=True, random_state=42)
    
    unbalanced_df_list.append(df_rating_unbalanced)

#  Combine all ratings
df_unbalanced = pd.concat(unbalanced_df_list).sample(frac=1, random_state=42).reset_index(drop=True)


print("\nUnbalanced Dataset Distribution:\n", df_unbalanced['Rating'].value_counts())
df_unbalanced.head()
# Out:
# Remaining dataset shape after removing balanced: (6291, 3)
#
# Unbalanced Dataset Distribution:
#  Rating
# 4    1887
# 3    1572
# 5    1258
# 2     943
# 1     629
# Name: count, dtype: int64
#    Rating                                             Review  ReviewLength
# 0       4  Yum Jersey Mikes I freakin love their wheat br...           721
# 1       4  When I think of Richardsons I feel warm and co...          1236
# 2       5  Great sports bar Shows most UFC Boxing and WWE...           181
# 3       5  My favorite place by far and well worth the dr...           204
# 4       2  Our group was not pleased with the quality of ...           395

# %%
# Sort by Rating
df_unbalanced_sorted = df_unbalanced.sort_values(by='Rating').reset_index(drop=True)

# Check distribution again
print(df_unbalanced_sorted['Rating'].value_counts())

df_unbalanced_sorted.head()
# Out:
# Rating
# 4    1887
# 3    1572
# 5    1258
# 2     943
# 1     629
# Name: count, dtype: int64
#    Rating                                             Review  ReviewLength
# 0       1  There were 3 cars in the parking lot and peopl...           301
# 1       1  So a friend of mine went here last Friday and ...           295
# 2       1  I recently had a shit cleaned at the Intercont...           487
# 3       1  Bad customer service No one at the front desk ...           177
# 4       1  I recently had a shit cleaned at the Intercont...           487

# %%
df_unbalanced_sorted.to_csv(r"..\data\Unbalanced_product_reviews.csv", index=False)

df_unbalanced_sorted.to_excel(r"..\data\Unbalanced_product_reviews.xlsx", index=False)

print("Imalanced dataset files saved")
# Out:
# Imalanced dataset files saved

# %% [markdown]
# # Data Visualization of Imbalanced Data

# %% [markdown]
# # Rating Distribution (Bar Chart)

# %%
sns.countplot(x='Rating', data=df_unbalanced_sorted, color='skyblue')  
plt.title('Rating Distribution')
plt.xlabel('Rating')
plt.ylabel('Number of Reviews')
plt.show()

# %% [markdown]
# # Rating Distribution (Pie Chart)

# %%
rating_counts = df_unbalanced_sorted['Rating'].value_counts().sort_index()

# Labels and values
categories = rating_counts.index
values = rating_counts.values

# Plot pie chart
plt.pie(values, labels=categories, autopct='%1.1f%%', startangle=90)
plt.title("Rating Distribution ")
plt.show()

# %% [markdown]
# # Natural Language Processing (NLP)

# %% [markdown]
# # Balanced Dataset

# %% [markdown]
# # Lowercase All Text

# %%
df_balanced_sorted = df_balanced_sorted[['Rating', 'Review']]
# Convert Review text to lowercase
df_balanced_sorted['Review'] = df_balanced_sorted['Review'].str.lower()
# Reset index
df_balanced_sorted.reset_index(drop=True, inplace=True)

print(df_balanced_sorted.head())
print("Dataset shape:", df_balanced_sorted.shape)
# Out:
#    Rating                                             Review
# 0       1  got a padi and the tech stopped for a while to...
# 1       1  easily the worst burrito i have ever had it am...
# 2       1  we bought or second jura compressa coffee mach...
# 3       1  i purchased a pair of naot paris sandals 160 w...
# 4       1  i have been going to bosa off and on since the...
# Dataset shape: (10000, 2)

# %% [markdown]
# # Remove URL

# %%
def remove_url(text):
    url_pattern = re.compile(r'https?://\S+|www\.\S+')
    return url_pattern.sub('', text)  # Replace URLs with empty string

df_balanced_sorted['Review'] = df_balanced_sorted['Review'].apply(remove_url)

df_balanced_sorted['Review'].head()
# Out:
# 0    got a padi and the tech stopped for a while to...
# 1    easily the worst burrito i have ever had it am...
# 2    we bought or second jura compressa coffee mach...
# 3    i purchased a pair of naot paris sandals 160 w...
# 4    i have been going to bosa off and on since the...
# Name: Review, dtype: object

# %% [markdown]
# # Remove HTML tags

# %%
def remove_html_tags(text):
    pattern = re.compile('<.*?>')
    return pattern.sub(r'',text)
df_balanced_sorted['Review'] =df_balanced_sorted['Review'].apply(remove_html_tags)

df_balanced_sorted['Review'].head()
# Out:
# 0    got a padi and the tech stopped for a while to...
# 1    easily the worst burrito i have ever had it am...
# 2    we bought or second jura compressa coffee mach...
# 3    i purchased a pair of naot paris sandals 160 w...
# 4    i have been going to bosa off and on since the...
# Name: Review, dtype: object

# %% [markdown]
# # Remove emojis, punctuation and special characters

# %%
import string

punctuation_list = string.punctuation
print(f'The punctuations are {punctuation_list}')
# Out:
# The punctuations are !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~

# %%
def clean_text_punct(text):
    # Remove punctuation
    for char in punctuation_list:
        text = text.replace(char, '')
    # Remove extra spaces
    text = ' '.join(text.split())
    return text

df_balanced_sorted['Review'] = df_balanced_sorted['Review'].apply(clean_text_punct)
df_balanced_sorted['Review'].head()
# Out:
# 0    got a padi and the tech stopped for a while to...
# 1    easily the worst burrito i have ever had it am...
# 2    we bought or second jura compressa coffee mach...
# 3    i purchased a pair of naot paris sandals 160 w...
# 4    i have been going to bosa off and on since the...
# Name: Review, dtype: object

# %% [markdown]
# # Showing stopwords

# %%
import spacy
nlp = spacy.load("en_core_web_sm")

def show_stopwords_in_text(text):
    doc = nlp(text)
    present_stopwords = [token.text for token in doc if token.is_stop]
    return present_stopwords

df_balanced_sorted['Stopwords_in_Review'] = df_balanced_sorted['Review'].apply(show_stopwords_in_text)
df_balanced_sorted[['Review', 'Stopwords_in_Review']].head()
# Out:
#                                               Review  \
# 0  got a padi and the tech stopped for a while to...
# 1  easily the worst burrito i have ever had it am...
# 2  we bought or second jura compressa coffee mach...
# 3  i purchased a pair of naot paris sandals 160 w...
# 4  i have been going to bosa off and on since the...
#
#                                  Stopwords_in_Review
# 0  [a, and, the, for, a, while, to, then, i, a, t...
# 1  [the, i, have, ever, had, it, my, that, anyone...
# 2  [we, or, from, it, was, an, over, after, it, t...
# 3  [i, a, of, with, at, the, i, but, to, i, up, m...
# 4  [i, have, been, to, off, and, on, since, they,...

# %% [markdown]
# # Remove stopwords

# %%
def remove_stopwords(text):
    doc = nlp(text)
    filtered_text = " ".join([token.text for token in doc if not token.is_stop])
    return filtered_text

df_balanced_sorted['Review'] = df_balanced_sorted['Review'].apply(remove_stopwords)
df_balanced_sorted['Review'].head()
# Out:
# 0    got padi tech stopped eat got new tech finish ...
# 1    easily worst burrito amazes choose eat chain b...
# 2    bought second jura compressa coffee machine su...
# 3    purchased pair naot paris sandals 160 tax shoe...
# 4    going bosa opened bad experience stop tell rig...
# Name: Review, dtype: object

# %% [markdown]
# # Apply Lemmatization

# %%
def lemmatize_text(text):
    doc = nlp(text)
    lemma_list = [token.lemma_ for token in doc]              # list format
    lemma_joined = " ".join(lemma_list)                       # joined format
    return pd.Series([lemma_list, lemma_joined])


df_balanced_sorted[['Review_List', 'REVIEW']] = df_balanced_sorted['Review'].apply(lemmatize_text)

print("List format:\n", df_balanced_sorted['REVIEW'].head())
print("\nJoined format:\n", df_balanced_sorted['REVIEW'].head())
# Out:
# List format:
#  0    get padi tech stop eat get new tech finish ped...
# 1    easily bad burrito amaze choose eat chain bet ...
# 2    buy second jura compressa coffee machine sur l...
# 3    purchase pair naot paris sandal 160 tax shoe m...
# 4    go bosa open bad experience stop tell right st...
# Name: REVIEW, dtype: object
#
# Joined format:
#  0    get padi tech stop eat get new tech finish ped...
# 1    easily bad burrito amaze choose eat chain bet ...
# 2    buy second jura compressa coffee machine sur l...
# 3    purchase pair naot paris sandal 160 tax shoe m...
# 4    go bosa open bad experience stop tell right st...
# Name: REVIEW, dtype: object

# %% [markdown]
# # Filter out reviews with: Fewer than minimum words and Excessively long text

# %%
# Calculate word count for each review
df_balanced_sorted['Word_Count'] = df_balanced_sorted['REVIEW'].apply(lambda x: len(x.split()))

df_balanced_sorted_filtered = df_balanced_sorted[(df_balanced_sorted['Word_Count'] >= 3) & (df_balanced_sorted['Word_Count'] <= 200)]

# Check the filtered dataset
print("Original dataset shape:", df_balanced_sorted.shape)
print("Filtered dataset shape:", df_balanced_sorted_filtered.shape)
df_balanced_sorted_filtered[['REVIEW', 'Word_Count']].head()
# Out:
# Original dataset shape: (10000, 6)
# Filtered dataset shape: (9734, 6)
#                                               REVIEW  Word_Count
# 0  get padi tech stop eat get new tech finish ped...          31
# 1  easily bad burrito amaze choose eat chain bet ...          14
# 2  buy second jura compressa coffee machine sur l...          50
# 3  purchase pair naot paris sandal 160 tax shoe m...          87
# 4  go bosa open bad experience stop tell right st...          89

# %% [markdown]
# # Visualization

# %%
sns.countplot(x='Rating', data=df_balanced_sorted_filtered, color='skyblue')
plt.title('Review Count per Rating')
plt.xlabel('Rating')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# # Create Balanced Dataset

# %%
min_count = 2000  

# List to hold balanced DataFrames
balanced_df_list = []

# Loop through each unique rating
for rating in df_balanced_sorted_filtered['Rating'].unique():
    df_rating = df_balanced_sorted_filtered[df_balanced_sorted_filtered['Rating'] == rating][['REVIEW', 'Rating']]
    
    if len(df_rating) < min_count:
        # Oversample minority class (with replacement)
        df_rating_balanced = df_rating.sample(min_count, replace=True, random_state=42)
    else:
        # Undersample majority class (without replacement)
        df_rating_balanced = df_rating.sample(min_count, replace=False, random_state=42)
    
    balanced_df_list.append(df_rating_balanced)

# Concatenate all ratings and shuffle
df_balanced_final = pd.concat(balanced_df_list).sample(frac=1, random_state=42).reset_index(drop=True)

# Check rating distribution
print("Balanced dataset distribution:\n", df_balanced_final['Rating'].value_counts())

# Shape of the balanced dataset
print("Balanced dataset shape:", df_balanced_final.shape)


df_balanced_final.head()
# Out:
# Balanced dataset distribution:
#  Rating
# 4    2000
# 3    2000
# 1    2000
# 2    2000
# 5    2000
# Name: count, dtype: int64
# Balanced dataset shape: (10000, 2)
#                                               REVIEW  Rating
# 0  awesome job rejuvenating bar dark dive bar gre...       4
# 1  ok great supposedly good steak joint ambiance ...       3
# 2  theater problem fact come theater break driver...       1
# 3  baja fresh clean fast hell lot well mcdonald u...       3
# 4  create monster bring family chipotle time year...       3

# %% [markdown]
# # Data Visualization

# %% [markdown]
# # Bar plot: Review count per rating

# %%
sns.countplot(x='Rating', data=df_balanced_final, color='skyblue')
plt.title('Review Count per Rating')
plt.xlabel('Rating')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# # Word count

# %%
df_balanced_final.loc[:, 'Word_Count'] = df_balanced_final['REVIEW'].str.split().str.len()


df_balanced_final[['REVIEW', 'Word_Count']].head()
# Out:
#                                               REVIEW  Word_Count
# 0  awesome job rejuvenating bar dark dive bar gre...          29
# 1  ok great supposedly good steak joint ambiance ...          10
# 2  theater problem fact come theater break driver...          40
# 3  baja fresh clean fast hell lot well mcdonald u...          26
# 4  create monster bring family chipotle time year...          37

# %% [markdown]
# # Histogram for Word Count

# %%
sns.histplot(df_balanced_final['Word_Count'], bins=30, kde=True, color='skyblue')
plt.title('Word Count Distribution in Reviews')
plt.xlabel('Number of Words')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# # Box Plot: Word count by Rating

# %%
sns.boxplot(x='Rating', y='Word_Count', data=df_balanced_final, color='lightgreen')
plt.title('Word Count Distribution by Rating')
plt.xlabel('Rating')
plt.ylabel('Word Count')
plt.show()

# %% [markdown]
# # full sample reviews per rating

# %%
for rating, group in df_balanced_final.groupby('Rating'):
    print(f"\n--- Rating: {rating} ---\n")
    sample_reviews = df_balanced_final[df_balanced_final['Rating'] == rating]['REVIEW'].sample(
        n=min(10, len(df_balanced_final[df_balanced_final['Rating'] == rating])),
        random_state=42)
    for i, review in enumerate(sample_reviews, 1):
        print(f"{i}. {review}\n")
# Out:
# --- Rating: 1 ---
#
# 1. boyfriend try place year not food unspectacular not hot price bit high s restaurant southern dobson serve well food decor tacky paint mural appeal clientele lastly staff nice
#
# ...

# %% [markdown]
# # Shuffle the dataset

# %%
# Shuffle the balanced dataset
df_shuffled = df_balanced_final.sample(frac=1, random_state=42).reset_index(drop=True)


df_shuffled[['REVIEW', 'Rating']].head()
# Out:
#                                               REVIEW  Rating
# 0  vibe exude place pure awesomeness reminiscent ...       4
# 1  favorite brunch spot cheap come admire arcadia...       5
# 2  place not food ok well chinese option price tr...       3
# 3  usually shop store convenient good price selec...       3
# 4  remember say trivium good thing place get rid ...       1

# %% [markdown]
# # Train-Test Split

# %%
from sklearn.model_selection import train_test_split

X = df_balanced_final['REVIEW']   # Text data
y = df_balanced_final['Rating']          # Target labels

# Stratified split to maintain class balance
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)

print("Training set size:", len(X_train))
print("Test set size:", len(X_test))
# Out:
# Training set size: 8000
# Test set size: 2000

# %% [markdown]
# # Preprocessing

# %%
nlp = spacy.load('en_core_web_sm')

def spacy_preprocess(text):
    doc = nlp(text.lower())  # Lowercase and tokenize
    tokens = [token.lemma_ for token in doc if not token.is_stop and token.is_alpha]
    return ' '.join(tokens)

# %%
# Preprocess training set
X_train_processed = X_train.apply(spacy_preprocess)

# Preprocess test set
X_test_processed = X_test.apply(spacy_preprocess)

print("X_train_preprocessed:")
print(X_train_processed.head())
print("X_test_preprocessed:")
print(X_test_processed.head())
# Out:
# X_train_preprocessed:
# 2203    pure fitness like contract people actually wor...
# 9737    una de las mejores universidade del mundo es b...
# 8977    avon pris le tour guid pour avoir une meilleur...
# 8396    surprised place close start asu come ingredien...
# 4713    consider consider norm workout facility place ...
# Name: REVIEW, dtype: object
# X_test_preprocessed:
# 4220    sadly new owner come change menu fav barbecue ...
# 1413               disappoint actually look campus bother
# 2355    decent lunch day coworker happy hour work food...
# 1988    stroll harvard yard time daughter graduate bit...
# 6214    bad quality ingredient order red curry beef be...
# Name: REVIEW, dtype: object

# %% [markdown]
# # Vectorize text using:TF-IDF

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf_vectorizer = TfidfVectorizer(max_features=5000,ngram_range=(1,2), stop_words='english')

X_train_tfidf = tfidf_vectorizer.fit_transform(X_train_processed)
print("TF-IDF training set shape:", X_train_tfidf.shape)

X_test_tfidf = tfidf_vectorizer.transform(X_test_processed)
print("TF-IDF test set shape:", X_test_tfidf.shape)
# Out:
# TF-IDF training set shape: (8000, 5000)
# TF-IDF test set shape: (2000, 5000)

# %%
print("Number of features in TF-IDF:", len(tfidf_vectorizer.get_feature_names_out()))
print("Sample features:", tfidf_vectorizer.get_feature_names_out()[:30])
# Out:
# Number of features in TF-IDF: 5000
# Sample features: ['ability' 'able' 'absolute' 'absolutely' 'absolutely love' 'ac'
#  'academic' 'accent' 'accept' 'acceptable' 'access' 'accessible'
#  'accessory' 'accommodate' 'accommodation' 'accompany' 'accomplishment'
#  'accord' 'account' 'acknowledge' 'act' 'act like' 'action' 'active'
#  'activity' 'actual' 'actually' 'actually clean' 'actually kinda'
#  'actually taste']

# %% [markdown]
# # Original Reviews and Ratings for Training and Test Sets

# %%
# Training set
print("REVIEW and Rating from training set:")
train_df_sample = pd.DataFrame({'REVIEW': X_train, 'Rating': y_train}).reset_index(drop=True)
print(train_df_sample.head(), "\n")  # Added \n for separation

# Test set
print("REVIEW and Rating from test set:")
test_df_sample = pd.DataFrame({'REVIEW': X_test, 'Rating': y_test}).reset_index(drop=True)
print(test_df_sample.head())
# Out:
# REVIEW and Rating from training set:
#                                               REVIEW  Rating
# 0  pure fitness like contract people go actually ...       1
# 1  una de las mejores universidade del mundo es b...       4
# 2  avon pris le tour guid pour avoir une meilleur...       3
# 3  surprised place not closed go start go asu com...       1
# 4  consider consider norm workout facility place ...       1
#
# REVIEW and Rating from test set:
#                                               REVIEW  Rating
# 0  sadly new owner come change menu fav barbecue ...       1
# 1     disappoint not actually look campus not bother       2
# 2  decent lunch day coworker happy hour work food...       3
# 3  stroll harvard yard time daughter graduate bit...       5
# 4  bad quality ingredient order red curry beef be...       1

# %% [markdown]
# # Top TF-IDF Features per Review with Corresponding Ratings

# %%
def top_tfidf_features_per_review(tfidf_matrix, feature_names, ratings, top_n=5):
  
    # Ensure dense format
    if not isinstance(tfidf_matrix, np.ndarray):
        tfidf_dense = tfidf_matrix.toarray()
    else:
        tfidf_dense = tfidf_matrix

    top_features_list = []

    for i in range(tfidf_dense.shape[0]):
        row = tfidf_dense[i]
        top_indices = row.argsort()[-top_n:][::-1]  # Indices of top N features
        top_features = [feature_names[idx] for idx in top_indices]
        top_scores = [row[idx] for idx in top_indices]
        
        top_features_list.append({
            'Rating': ratings.iloc[i] if hasattr(ratings, 'iloc') else ratings[i],
            'Top_Features': top_features,
            'TF-IDF_Scores': top_scores
        })

    return pd.DataFrame(top_features_list)

feature_names = tfidf_vectorizer.get_feature_names_out()
top_features_df = top_tfidf_features_per_review(X_train_tfidf, feature_names, y_train, top_n=5)

top_features_df.head()
# Out:
#    Rating                                       Top_Features  \
# 0       1          [fitness, sign, sore, online, commission]
# 1       4                     [historia, la, una, es, bueno]
# 2       3                     [une, le, pour, le parc, parc]
# 3       1  [pita, time table, maker, place close, meat ta...
# 4       1      [consider, membership, blah, place, location]
#
#                                        TF-IDF_Scores
# 0  [0.302614434239601, 0.28141139887546757, 0.273...
# 1  [0.41935816141521415, 0.4034142753981449, 0.34...
# 2  [0.6456452315488554, 0.37231324364920754, 0.35...
# 3  [0.3598874382015234, 0.22747100114037383, 0.21...
# 4  [0.39612432699213845, 0.2962130494124775, 0.26...

# %% [markdown]
# #  Imbalanced dataset (NLP)

# %% [markdown]
# # Lowercase All Text

# %%
df_unbalanced_sorted = df_unbalanced_sorted[['Rating', 'Review']]
# Convert Review text to lowercase
df_unbalanced_sorted['Review'] = df_unbalanced_sorted['Review'].str.lower()
# Reset index
df_unbalanced_sorted.reset_index(drop=True, inplace=True)

print("Dataset shape:", df_unbalanced_sorted.shape)
df_unbalanced_sorted.head()
# Out:
# Dataset shape: (6289, 2)
#    Rating                                             Review
# 0       1  there were 3 cars in the parking lot and peopl...
# 1       1  so a friend of mine went here last friday and ...
# 2       1  i recently had a shit cleaned at the intercont...
# 3       1  bad customer service no one at the front desk ...
# 4       1  i recently had a shit cleaned at the intercont...

# %% [markdown]
# # Remove URL

# %%
def remove_url(text):
    url_pattern = re.compile(r'https?://\S+|www\.\S+')
    return url_pattern.sub('', text)  # Replace URLs with empty string

df_unbalanced_sorted['Review'] = df_unbalanced_sorted['Review'].apply(remove_url)

df_unbalanced_sorted['Review'].head()
# Out:
# 0    there were 3 cars in the parking lot and peopl...
# 1    so a friend of mine went here last friday and ...
# 2    i recently had a shit cleaned at the intercont...
# 3    bad customer service no one at the front desk ...
# 4    i recently had a shit cleaned at the intercont...
# Name: Review, dtype: object

# %% [markdown]
# # Remove HTML tags

# %%
def remove_html_tags(text):
    pattern = re.compile('<.*?>')
    return pattern.sub(r'',text)
df_unbalanced_sorted['Review'] =df_unbalanced_sorted['Review'].apply(remove_html_tags)

df_unbalanced_sorted['Review'].head()
# Out:
# 0    there were 3 cars in the parking lot and peopl...
# 1    so a friend of mine went here last friday and ...
# 2    i recently had a shit cleaned at the intercont...
# 3    bad customer service no one at the front desk ...
# 4    i recently had a shit cleaned at the intercont...
# Name: Review, dtype: object

# %% [markdown]
# # Remove emojis, punctuation and special characters

# %%
import string

punctuation_list = string.punctuation
print(f'The punctuations are {punctuation_list}')
# Out:
# The punctuations are !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~

# %%
def clean_text_punct(text):
    # Remove punctuation
    for char in punctuation_list:
        text = text.replace(char, '')
    # Remove extra spaces
    text = ' '.join(text.split())
    return text

df_unbalanced_sorted['Review'] = df_unbalanced_sorted['Review'].apply(clean_text_punct)
df_unbalanced_sorted['Review'].head()
# Out:
# 0    there were 3 cars in the parking lot and peopl...
# 1    so a friend of mine went here last friday and ...
# 2    i recently had a shit cleaned at the intercont...
# 3    bad customer service no one at the front desk ...
# 4    i recently had a shit cleaned at the intercont...
# Name: Review, dtype: object

# %% [markdown]
# # Showing stopwords

# %%
import spacy
nlp = spacy.load("en_core_web_sm")

def show_stopwords_in_text(text):
    doc = nlp(text)
    present_stopwords = [token.text for token in doc if token.is_stop]
    return present_stopwords

df_unbalanced_sorted['Stopwords_in_Review'] = df_unbalanced_sorted['Review'].apply(show_stopwords_in_text)
df_unbalanced_sorted[['Review', 'Stopwords_in_Review']].head()
# Out:
#                                               Review  \
# 0  there were 3 cars in the parking lot and peopl...
# 1  so a friend of mine went here last friday and ...
# 2  i recently had a shit cleaned at the intercont...
# 3  bad customer service no one at the front desk ...
# 4  i recently had a shit cleaned at the intercont...
#
#                                  Stopwords_in_Review
# 0  [there, were, in, the, and, to, the, but, the,...
# 1  [so, a, of, mine, here, last, and, they, were,...
# 2  [i, had, a, at, the, in, not, i, only, that, b...
# 3  [no, one, at, the, front, for, they, the, on, ...
# 4  [i, had, a, at, the, in, not, i, only, that, b...

# %% [markdown]
# # Remove stopwords

# %%
def remove_stopwords(text):
    doc = nlp(text)
    filtered_text = " ".join([token.text for token in doc if not token.is_stop])
    return filtered_text

df_unbalanced_sorted['Review'] = df_unbalanced_sorted['Review'].apply(remove_stopwords)
df_unbalanced_sorted['Review'].head()
# Out:
# 0    3 cars parking lot people walking door young l...
# 1    friend went friday double charged bartender to...
# 2    recently shit cleaned intercontinental hotel h...
# 3    bad customer service desk thirty minutes plus ...
# 4    recently shit cleaned intercontinental hotel h...
# Name: Review, dtype: object

# %% [markdown]
# # Apply Lemmatization

# %%
def lemmatize_text(text):
    doc = nlp(text)
    lemma_list = [token.lemma_ for token in doc]              # list format
    lemma_joined = " ".join(lemma_list)                       # joined format
    return pd.Series([lemma_list, lemma_joined])


df_unbalanced_sorted[['Review_List', 'REVIEW']] = df_unbalanced_sorted['Review'].apply(lemmatize_text)

print("List format:\n", df_unbalanced_sorted['Review_List'].head())
print("\nJoined format:\n", df_unbalanced_sorted['REVIEW'].head())
# Out:
# List format:
#  0    [3, car, parking, lot, people, walk, door, you...
# 1    [friend, go, friday, double, charge, bartender...
# 2    [recently, shit, clean, intercontinental, hote...
# 3    [bad, customer, service, desk, thirty, minute,...
# 4    [recently, shit, clean, intercontinental, hote...
# Name: Review_List, dtype: object
#
# Joined format:
#  0    3 car parking lot people walk door young lady ...
# 1    friend go friday double charge bartender take ...
# 2    recently shit clean intercontinental hotel hon...
# 3    bad customer service desk thirty minute plus l...
# 4    recently shit clean intercontinental hotel hon...
# Name: REVIEW, dtype: object

# %% [markdown]
# # Filter out reviews with: Fewer than minimum words and Excessively long text

# %%
# Calculate word count for each review
df_unbalanced_sorted['Word_Count'] = df_unbalanced_sorted['REVIEW'].apply(lambda x: len(x.split()))

df_unbalanced_sorted_filtered = df_unbalanced_sorted[(df_unbalanced_sorted['Word_Count'] >= 3) & (df_unbalanced_sorted['Word_Count'] <= 200)]

# Check the filtered dataset
print("Original dataset shape:", df_unbalanced_sorted.shape)
print("Filtered dataset shape:", df_unbalanced_sorted_filtered.shape)
df_unbalanced_sorted_filtered[['REVIEW', 'Word_Count']].head()
# Out:
# Original dataset shape: (6289, 6)
# Filtered dataset shape: (6118, 6)
#                                               REVIEW  Word_Count
# 0  3 car parking lot people walk door young lady ...          28
# 1  friend go friday double charge bartender take ...          26
# 2  recently shit clean intercontinental hotel hon...          43
# 3  bad customer service desk thirty minute plus l...          16
# 4  recently shit clean intercontinental hotel hon...          43

# %% [markdown]
# # Bar plot: Review count per rating on  Imbalanced Dataset (nlp)

# %%
sns.countplot(x='Rating', data=df_unbalanced_sorted_filtered, color='skyblue')
plt.title('Review Count per Rating')
plt.xlabel('Rating')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# # Rating Distribution (Pie Chart)

# %%
rating_counts = df_unbalanced_sorted_filtered['Rating'].value_counts().sort_index()

# Labels and values
categories = rating_counts.index
values = rating_counts.values

# Plot pie chart
plt.pie(values, labels=categories, autopct='%1.1f%%', startangle=90)
plt.title("Rating Distribution ")
plt.show()

# %% [markdown]
# # Word count

# %%
df_unbalanced_sorted_filtered.loc[:, 'Word_Count'] = df_unbalanced_sorted_filtered['REVIEW'].str.split().str.len()

df_unbalanced_sorted_filtered[['REVIEW', 'Word_Count']].head()
# Out:
#                                               REVIEW  Word_Count
# 0  3 car parking lot people walk door young lady ...          28
# 1  friend go friday double charge bartender take ...          26
# 2  recently shit clean intercontinental hotel hon...          43
# 3  bad customer service desk thirty minute plus l...          16
# 4  recently shit clean intercontinental hotel hon...          43

# %% [markdown]
# # Histogram for Word Count

# %%
sns.histplot(df_unbalanced_sorted_filtered['Word_Count'], bins=30, kde=True, color='skyblue')
plt.title('Word Count Distribution in Reviews')
plt.xlabel('Number of Words')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# # Box Plot: Word count by Rating

# %%
sns.boxplot(x='Rating', y='Word_Count', data=df_unbalanced_sorted_filtered, color='lightgreen')
plt.title('Word Count Distribution by Rating')
plt.xlabel('Rating')
plt.ylabel('Word Count')
plt.show()

# %% [markdown]
# # full sample reviews per rating

# %%
for rating, group in df_unbalanced_sorted_filtered.groupby('Rating'):
    print(f"\n--- Rating: {rating} ---\n")
    sample_reviews = df_unbalanced_sorted_filtered[df_unbalanced_sorted_filtered['Rating'] == rating]['REVIEW'].sample(
        n=min(10, len(df_unbalanced_sorted_filtered[df_unbalanced_sorted_filtered['Rating'] == rating])),
        random_state=42)
    for i, review in enumerate(sample_reviews, 1):
        print(f"{i}. {review}\n")
# Out:
# --- Rating: 1 ---
#
# 1. place whitetrash chipotle food mediocre well mean seriously steal chipotle idea s creativity habenaro salsa flavorless hot seriously ask hot yellowish tomato concoction people not handle real salsa chipotle hot salsa hot well fast americanized mexican food course real deal like chiptole crap qdoba try serve chicken season highly spicedherbed barely taste chicken fajita veggie product look low quality oxidize guacamole lettuce meat look unappetizing level chipotle twice time denver reason think well maybe management food good chiptole wannabe employee dumber bag frijol place bad mexican food pre burrito 711 burrito taco bell disgusting food
#
# 2. management group location need well effort control number people jump theater experience theater bad theater feel complete money grab
#
# 3. management group location need well effort control number people jump theater experience theater bad theater feel complete money grab
#
# ...

# %% [markdown]
# # Shuffle the dataset

# %%
# Shuffle the Imbalanced dataset
df_shuffled_unbalance = df_unbalanced_sorted_filtered.sample(frac=1, random_state=42).reset_index(drop=True)

# Select only Review and Rating columns
df_shuffled_unbalance_simple = df_shuffled_unbalance[['REVIEW', 'Rating']]

# Display the first few rows
df_shuffled_unbalance_simple.head()
# Out:
#                                               REVIEW  Rating
# 0  ne peut aller boston sans se rendre sur le cam...       5
# 1  enjoy hawhvad walk tour book mid morning slot ...       4
# 2  si vas boston tienes dejar un tiempo para visi...       4
# 3  meet friend happy hour day old el paso bbq kno...       3
# 4  find little hot spot yelp phone navigate not f...       5

# %% [markdown]
# # Train-Test Split

# %%
from sklearn.model_selection import train_test_split

X = df_unbalanced_sorted_filtered['REVIEW']   # Text data
y = df_unbalanced_sorted_filtered['Rating']          # Target labels

# Stratified split to maintain class balance
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)

print("Training set size:", len(X_train))
print("Test set size:", len(X_test))
# Out:
# Training set size: 4894
# Test set size: 1224

# %% [markdown]
# # Preprocessing

# %%
nlp = spacy.load('en_core_web_sm')

def spacy_preprocess(text):
    doc = nlp(text.lower())  # Lowercase and tokenize
    tokens = [token.lemma_ for token in doc if not token.is_stop and token.is_alpha]
    return ' '.join(tokens)

# Preprocess training set
X_train_processed = X_train.apply(spacy_preprocess)

# Preprocess test set
X_test_processed = X_test.apply(spacy_preprocess)

print("X_train_preprocessed:")
print(X_train_processed.head())
print("X_test_preprocessed:")
print(X_test_processed.head())
# Out:
# X_train_preprocessed:
# 3242    parking lot small watch car door seafood authe...
# 4404    good asian food price range chicken chewy like...
# 4325    short review order talk freakin donut az good ...
# 3585    airport exactly look forexpect establishment c...
# 3581    meet josh owner night commend sleek lounge gre...
# Name: REVIEW, dtype: object
# X_test_preprocessed:
# 110     think chef silvana esparza locate restaurant c...
# 426     receive pedicure manicure location usually pre...
# 1654    difficult review write family start eat open w...
# 1045    want chime place vegetarianunfriendly funny dr...
# 1807    pcos minutos en subte desde el centro de bosto...
# Name: REVIEW, dtype: object

# %% [markdown]
# # Vectorize text using:TF-IDF

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf_vectorizer = TfidfVectorizer(max_features=5000,ngram_range=(1,2), stop_words='english')

X_train_tfidf = tfidf_vectorizer.fit_transform(X_train_processed)
print("TF-IDF training set shape:", X_train_tfidf.shape)

X_test_tfidf = tfidf_vectorizer.transform(X_test_processed)
print("TF-IDF test set shape:", X_test_tfidf.shape)
# Out:
# TF-IDF training set shape: (4894, 5000)
# TF-IDF test set shape: (1224, 5000)

# %%
print("Number of features in TF-IDF:", len(tfidf_vectorizer.get_feature_names_out()))
print("Sample features:", tfidf_vectorizer.get_feature_names_out()[:30])
# Out:
# Number of features in TF-IDF: 5000
# Sample features: ['aaron' 'abacus' 'aber' 'ability' 'able' 'able overlook' 'abrupt'
#  'absolute' 'absolutely' 'absolutely disgusting' 'absolutely love'
#  'absurd' 'abundance' 'ac' 'academic' 'accept' 'acceptable' 'access'
#  'accessible' 'accommodate' 'accompany' 'ache' 'acknowledge'
#  'acknowledge repeat' 'acknowledgement' 'acoustic' 'act'
#  'act inconvenience' 'active' 'activity']

# %% [markdown]
# # Original Reviews and Ratings for Training and Test Sets

# %%
# Training set
print("REVIEW and Rating from training set:")
train_df_sample = pd.DataFrame({'REVIEW': X_train, 'Rating': y_train}).reset_index(drop=True)
print(train_df_sample.head(), "\n")  # Display first 5 rows

# Test set
print("REVIEW and Rating from test set:")
test_df_sample = pd.DataFrame({'REVIEW': X_test, 'Rating': y_test}).reset_index(drop=True)
print(test_df_sample.head())
# Out:
# REVIEW and Rating from training set:
#                                               REVIEW  Rating
# 0  parking lot small watch car door seafood authe...       4
# 1  good get asian food price range chicken not ch...       4
# 2  short review order talk freakin donut az good ...       4
# 3  airport exactly look forexpect establishment c...       4
# 4  meet josh owner night commend sleek lounge gre...       4
#
# REVIEW and Rating from test set:
#                                               REVIEW  Rating
# 0  think chef silvana esparza locate restaurant c...       1
# 1  receive pedicure manicure location usually pre...       1
# 2  difficult review write family start eat open w...       3
# 3  want chime place vegetarianunfriendly funny dr...       2
# 4  pcos minutos en subte desde el centro de bosto...       3

# %% [markdown]
# # Top TF-IDF Features per Review with Corresponding Ratings

# %%
def top_tfidf_features_per_review(tfidf_matrix, feature_names, ratings, top_n=5):
  
    # Ensure dense format
    if not isinstance(tfidf_matrix, np.ndarray):
        tfidf_dense = tfidf_matrix.toarray()
    else:
        tfidf_dense = tfidf_matrix

    top_features_list = []

    for i in range(tfidf_dense.shape[0]):
        row = tfidf_dense[i]
        top_indices = row.argsort()[-top_n:][::-1]  # Indices of top N features
        top_features = [feature_names[idx] for idx in top_indices]
        top_scores = [row[idx] for idx in top_indices]
        
        top_features_list.append({
            'Rating': ratings.iloc[i] if hasattr(ratings, 'iloc') else ratings[i],
            'Top_Features': top_features,
            'TF-IDF_Scores': top_scores
        })

    return pd.DataFrame(top_features_list)

feature_names = tfidf_vectorizer.get_feature_names_out()
top_features_df = top_tfidf_features_per_review(X_train_tfidf, feature_names, y_train, top_n=5)

top_features_df.head()
# Out:
#    Rating                                       Top_Features  \
# 0       4      [seafood, medium, shrimp, cook, bring friend]
# 1       4  [teriyaki, broccoli, asian, chicken, restauran...
# 2       4  [donut, chocolate, stale, little place, place ...
# 3       4       [sky harbor, harbor, sky, airport, terminal]
# 4       4      [include, ipa, good music, charm, great beer]
#
#                                        TF-IDF_Scores
# 0  [0.33917047521840005, 0.3184588386725889, 0.27...
# 1  [0.4043702784261189, 0.4043702784261189, 0.335...
# 2  [0.6521478340088996, 0.3095228555844842, 0.224...
# 3  [0.45132233199914273, 0.45132233199914273, 0.3...
# 4  [0.3030655923626545, 0.24431690354226313, 0.24...
